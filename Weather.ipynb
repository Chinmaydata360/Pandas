# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\win\\OneDrive\\Desktop\\pandas_project_final\\Weather.csv")

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# find all unique "Wind Speed" in dataset

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
# find the number of time the weather in exactly clear

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
Clear=df[df["Weather"]=="Clear"].shape[0]

# %%
print("The weather is exactly clear ",Clear," time")
# Out:
# The weather is exactly clear  1326  time

# %%
# find the number of time when wind speed was exactly 4 km/h

# %%
wind_speed=df[df["Wind Speed_km/h"]==4].shape[0]

# %%
print("wind_speed was 4km/h ",wind_speed," time")
# Out:
# wind_speed was 4km/h  474  time

# %%
# find all null values in dataset

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#rename the column name of weather to weather condition

# %%
df.rename(columns={"Weather":"weather condition"},inplace=True)

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# what is mean of visibility

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
#what is mean viisiblity

# %%
Visiblity_mean=round(df["Visibility_km"].mean(),2)

# %%
print("Mean Visibility is ",Visiblity_mean)
# Out:
# Mean Visibility is  27.66

# %%
# mean visiblity per day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date/Time          8784 non-null   datetime64[ns]
#  1   Temp_C             8784 non-null   float64
#  2   Dew Point Temp_C   8784 non-null   float64
#  3   Rel Hum_%          8784 non-null   int64
#  4   Wind Speed_km/h    8784 non-null   int64
#  5   Visibility_km      8784 non-null   float64
#  6   Press_kPa          8784 non-null   float64
#  7   weather condition  8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
df["Date/Time"]=pd.to_datetime(df["Date/Time"])

# %%
df["Date"]=df["Date/Time"].dt.date

# %%
mean_vis_per_day=df.groupby("Date")["Visibility_km"].mean().reset_index()

# %%
mean_vis_per_day
# Out:
#            Date  Visibility_km
# 0    2012-01-01       9.862500
# 1    2012-01-02      24.425000
# 2    2012-01-03      24.120833
# 3    2012-01-04      19.595833
# 4    2012-01-05      24.362500
# ..          ...            ...
# 361  2012-12-27       6.104167
# 362  2012-12-28      27.212500
# 363  2012-12-29       8.983333
# 364  2012-12-30      23.866667
# 365  2012-12-31      14.179167
#
# [366 rows x 2 columns]

# %%
# what is Standard Dev of pressure in data

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition        Date
# 0            8.0     101.24               Fog  2012-01-01
# 1            8.0     101.24               Fog  2012-01-01

# %%
pressure_std=round(df["Press_kPa"].std(),2)

# %%
print("Std of pressure is ",pressure_std)
# Out:
# Std of pressure is  0.84

# %%
# what is variance of Relative humidity

# %%
var_rel=round(df["Rel Hum_%"].var(),2)

# %%
print("Variance of relative humidity ",var_rel)
# Out:
# Variance of relative humidity  286.25

# %%
# find all instance where show is recorded

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition        Date
# 0            8.0     101.24               Fog  2012-01-01
# 1            8.0     101.24               Fog  2012-01-01

# %%
df["weather condition"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
number_time_snow=df[df["weather condition"].str.contains("Snow")].shape[0]

# %%
print("Number of time snow recorded ",number_time_snow)
# Out:
# Number of time snow recorded  583

# %%
#find all instance where wind speed is above 24 and visiblity is 25

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition        Date
# 0            8.0     101.24               Fog  2012-01-01
# 1            8.0     101.24               Fog  2012-01-01

# %%
df[(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]>25)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# 111  2012-01-05 15:00:00    -4.3             -12.0         55
# 350  2012-01-15 14:00:00   -16.0             -23.4         53
# 422  2012-01-18 14:00:00   -10.3             -17.6         55
# 423  2012-01-18 15:00:00   -10.4             -18.0         54
# ...                  ...     ...               ...        ...
# 8748 2012-12-30 12:00:00   -12.2             -15.7         75
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
#
#       Wind Speed_km/h  Visibility_km  Press_kPa weather condition        Date
# 109                26           48.3     100.40      Mainly Clear  2012-01-05
# ...

# %%
# what is the mean value of each column against each weather condition

# %%
mean_withall_weater_con=df.groupby("weather condition")[["Temp_C","Dew Point Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Press_kPa"]].mean().reset_index()

# %%
mean_withall_weater_con
# Out:
#                           weather condition     Temp_C  Dew Point Temp_C  \
# 0                                     Clear   6.825716          0.089367
# 1                                    Cloudy   7.970544          2.375810
# 2                                   Drizzle   7.353659          5.504878
# 3                               Drizzle,Fog   8.067500          7.033750
# 4                   Drizzle,Ice Pellets,Fog   0.400000         -0.700000
# 5                              Drizzle,Snow   1.050000          0.150000
# 6                          Drizzle,Snow,Fog   0.693333          0.120000
# 7                                       Fog   4.303333          3.159333
# 8                          Freezing Drizzle  -5.657143         -8.000000
# 9                      Freezing Drizzle,Fog  -2.533333         -4.183333
# 10                    Freezing Drizzle,Haze  -5.433333         -8.000000
# 11                    Freezing Drizzle,Snow  -5.109091         -7.072727
# ...

# %%
# what is the minimum & maxium value of each column against each weater condition

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition        Date
# 0            8.0     101.24               Fog  2012-01-01
# 1            8.0     101.24               Fog  2012-01-01

# %%
df.groupby("weather condition").min()
# Out:
#                                                   Date/Time  Temp_C  \
# weather condition
# Clear                                   2012-01-03 19:00:00   -23.3
# Cloudy                                  2012-01-01 17:00:00   -21.4
# Drizzle                                 2012-01-23 21:00:00     1.1
# Drizzle,Fog                             2012-01-23 20:00:00     0.0
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-17 15:00:00     0.9
# Drizzle,Snow,Fog                        2012-12-18 21:00:00     0.3
# Fog                                     2012-01-01 00:00:00   -16.0
# Freezing Drizzle                        2012-01-07 11:00:00    -9.0
# Freezing Drizzle,Fog                    2012-01-01 02:00:00    -6.4
# Freezing Drizzle,Haze                   2012-02-01 11:00:00    -5.8
# Freezing Drizzle,Snow                   2012-01-13 03:00:00    -8.3
# ...

# %%
df.groupby("weather condition").max()
# Out:
#                                                   Date/Time  Temp_C  \
# weather condition
# Clear                                   2012-12-30 20:00:00    32.8
# Cloudy                                  2012-12-31 06:00:00    30.5
# Drizzle                                 2012-12-22 01:00:00    18.8
# Drizzle,Fog                             2012-12-19 10:00:00    19.9
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-19 18:00:00     1.2
# Drizzle,Snow,Fog                        2012-12-22 03:00:00     1.1
# Fog                                     2012-12-29 10:00:00    20.8
# Freezing Drizzle                        2012-12-17 00:00:00    -2.3
# Freezing Drizzle,Fog                    2012-12-10 05:00:00    -0.3
# Freezing Drizzle,Haze                   2012-02-01 13:00:00    -5.0
# Freezing Drizzle,Snow                   2012-12-28 02:00:00    -3.3
# ...

# %%
# find all instances wheather is clear or visiblity is above 40

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition        Date
# 0            8.0     101.24               Fog  2012-01-01
# 1            8.0     101.24               Fog  2012-01-01

# %%
df[(df["weather condition"]=="Clear") | (df["Visibility_km"]>40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa weather condition        Date
# 67                 24           25.0     101.74             Clear  2012-01-03
# ...

# %%
""" find all instances 
A] weater is clear and relative humidity is grater that 50

or

B] Visiblity is above 40"""
# Out:
# ' find all instances \nA] weater is clear and relative humidity is grater that 50\n\nor\n\nB] Visiblity is above 40'

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition        Date
# 0            8.0     101.24               Fog  2012-01-01
# 1            8.0     101.24               Fog  2012-01-01

# %%
df[((df["weather condition"]=="Clear") & (df["Rel Hum_%"]>50) ) | (df["Visibility_km"]>40)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# 110  2012-01-05 14:00:00    -5.1             -10.7         65
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa weather condition        Date
# 106                17           48.3     100.45      Mainly Clear  2012-01-05
# ...

# %%
# find mean of visiblity hr wise

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa weather condition        Date
# 0            8.0     101.24               Fog  2012-01-01
# 1            8.0     101.24               Fog  2012-01-01

# %%
df["Date/Time"].dt.hour
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#         ..
# 8779    19
# 8780    20
# 8781    21
# 8782    22
# 8783    23
# Name: Date/Time, Length: 8784, dtype: int32

# %%
df["Hours"]=df["Date/Time"].dt.hour

# %%
df
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     weather condition  \
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
hour_vis=df.groupby("Hours")["Visibility_km"].mean().round(2).reset_index()

# %%
hour_vis
# Out:
#     Hours  Visibility_km
# 0       0          22.65
# 1       1          22.69
# 2       2          22.50
# 3       3          22.33
# 4       4          22.73
# 5       5          24.73
# 6       6          27.74
# 7       7          29.10
# 8       8          29.94
# 9       9          31.27
# 10     10          31.67
# 11     11          32.22
# 12     12          32.88
# 13     13          33.05
# 14     14          33.14
# 15     15          32.88
# 16     16          32.45
# 17     17          31.32
# 18     18          29.07
# 19     19          26.51
# 20     20          24.25
# 21     21          22.94
# 22     22          23.05
# 23     23          22.83
